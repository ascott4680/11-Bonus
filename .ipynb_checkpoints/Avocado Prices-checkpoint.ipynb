# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from pandas.plotting import autocorrelation_plot
from statsmodels.tsa.arima_model import ARIMA

# %%
#csv file read
read = "Resources/avocado.csv"

# Read with Pandas
avo = pd.read_csv(read)
avo.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
avo.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
#avo_group = avo.groupby("")
avo["year"].nunique()

phoenix = avo.loc[avo["region"]=="PhoenixTucson"]
conventional = phoenix.loc[phoenix['type']== 'conventional']

organic = phoenix.loc[phoenix['type']== 'organic']

# %%
conventional.plot(kind='line', x='Date', y='AveragePrice', color='seagreen', figsize=(10,5), 
                  label='Conventional Avocado', title='Average Avacado Price')

# %%
organic.head()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 10842           0  2015-12-27          1.72       7422.47  5038.15   906.49
# 10843           1  2015-12-20          1.79       6499.82  4879.21   919.88
# 10844           2  2015-12-13          1.72       6991.24  5065.07  1160.53
# 10845           3  2015-12-06          1.87       5936.27  4843.94   832.33
# 10846           4  2015-11-29          1.89       5175.81  4379.15   689.99
#
#        4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 10842   0.0     1477.83     1324.33      153.50          0.0  organic  2015
# 10843   0.0      700.73      679.05       21.68          0.0  organic  2015
# 10844   0.0      765.64      765.64        0.00          0.0  organic  2015
# 10845   0.0      260.00      260.00        0.00          0.0  organic  2015
# 10846   0.0      106.67      106.67        0.00          0.0  organic  2015
#
#               region
# 10842  PhoenixTucson
# 10843  PhoenixTucson
# 10844  PhoenixTucson
# 10845  PhoenixTucson
# 10846  PhoenixTucson

# %%
#phoenix['Date'] = pd.to_datetime(phoenix['Date'])


ax = plt.gca()

conventional.plot(kind='line',x='Date',y='AveragePrice', color='blue', label='Conventional',ax=ax)
organic.plot(kind='line',x='Date',y='AveragePrice', color='seagreen', label='Organic',figsize= (10,5),
             title='Avg. Conventional vs. Organic Price', ax=ax)


plt.show()

# %%
ax = plt.gca()

conventional.plot(kind='scatter',x='Total Bags',y='AveragePrice',label='Conventional',ax=ax)
organic.plot(kind='scatter',x='Total Bags',y='AveragePrice', color='seagreen', label='Organic',figsize= (10,5), 
             title='Organic vs. Conventional Total Bags Price', ax=ax)


plt.show()

# %%
ax = plt.gca()

conventional.plot(kind='scatter',x='Small Bags',y='AveragePrice',label='Small Bags',ax=ax)
conventional.plot(kind='scatter',x='Large Bags',y='AveragePrice', color='green', label='Large Bags',figsize= (10,5), ax=ax)
conventional.plot(kind='scatter',x='XLarge Bags',y='AveragePrice', color='red', label='XL Bags',figsize= (10,5), 
                  title='Bag Size vs Price Comparison Conventional',ax=ax)

plt.show()

# %%
ax = plt.gca()

organic.plot(kind='hist',x='Total Bags',y='AveragePrice',label='Organic',color='green', alpha=0.3, ax=ax)
conventional.plot(kind='hist',x='Total Bags',y='AveragePrice', color='seagreen', label='Conventional',figsize= (10,5), 
                  title='Organic vs. Conventional Price Spread', alpha=0.5, ax=ax)

plt.show()

# %%
#organic.plot(kind='box', x='Total Bags', y='AveragePrice')
fig,ax =fig.subplots(1,1,1)
ax1 = plt.box(organic['AveragePrice'])
ax2 = plt.box(conventional['AveragePrice'])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-deaf00cd7a02> in <module>
#       1 #organic.plot(kind='box', x='Total Bags', y='AveragePrice')
# ----> 2 fig,ax =fig.subplots(1,1,1)
#       3 ax1 = plt.box(organic['AveragePrice'])
#       4 ax2 = plt.box(conventional['AveragePrice'])
#       5
#
# NameError: name 'fig' is not defined

# %%
lol_df = conventional.groupby(['Date']).mean()
lol_df['AveragePrice'].std()
# Out:
# 0.17802600558461254

# %%
xd_df = organic.groupby(['Date']).mean()
xd_df['AveragePrice'].std()
# Out:
# 0.2755689828333419

# %%
lol_df['AveragePrice'].plot()
xd_df['AveragePrice'].plot()

# %%
xd_df.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume      4046     4225  4770  \
# Date
# 2015-01-04          51          1.12      17296.85  14569.66  1868.59   0.0
# 2015-01-11          50          1.36      14035.18  11523.29  1632.63   0.0
# 2015-01-18          49          1.36      12251.87  10248.57  1529.97   0.0
# 2015-01-25          48          1.54      10849.40   7988.43  1728.24   0.0
# 2015-02-01          47          1.18      13645.72  10810.58  2016.62   0.0
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags  year
# Date
# 2015-01-04      858.60      830.00       28.60          0.0  2015
# 2015-01-11      879.26      876.68        2.58          0.0  2015
# 2015-01-18      473.33      473.33        0.00          0.0  2015
# 2015-01-25     1132.73     1120.00       12.73          0.0  2015
# 2015-02-01      818.52      813.46        5.06          0.0  2015

# %%
decom = seasonal_decompose(xd_df['AveragePrice'],freq=12)

# %%
decom.plot()

# %%
model = sm.tsa.statespace.SARIMAX(xd_df['AveragePrice'],order=(0,1,0),seasonal_order=(1,1,1,12))
# Out:
# /anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   % freq, ValueWarning)

# %%
res = model.fit()
print(res.summary())
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                       AveragePrice   No. Observations:                  169
# Model:             SARIMAX(0, 1, 0)x(1, 1, 1, 12)   Log Likelihood                  58.920
# Date:                            Thu, 09 May 2019   AIC                           -111.839
# Time:                                    17:31:19   BIC                           -102.690
# Sample:                                01-04-2015   HQIC                          -108.123
#                                      - 03-25-2018
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L12       0.0524      0.104      0.506      0.613      -0.151       0.256
# ma.S.L12      -0.9855      1.005     -0.980      0.327      -2.956       0.985
# sigma2         0.0230      0.022      1.068      0.285      -0.019       0.065
# ===================================================================================
# Ljung-Box (Q):                       61.52   Jarque-Bera (JB):                 9.70
# Prob(Q):                              0.02   Prob(JB):                         0.01
# Heteroskedasticity (H):               0.69   Skew:                            -0.35
# Prob(H) (two-sided):                  0.19   Kurtosis:                         4.00
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
xd_df['forecast'] = res.predict(start=200,end=210,dynamic=True)
# Out:
# /anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/kalman_filter.py:1740: ValueWarning: Dynamic prediction specified to begin during out-of-sample forecasting period, and so has no effect.
#   ' effect.', ValueWarning)

# %%
xd_df.index.dtype
# Out:
# dtype('O')

# %%
decom2 = seasonal_decompose(lol_df['AveragePrice'],freq=12)

# %%
decom2.plot()
